# %%
# !pip3 install tensorflow-gpu
# !pip3 install keras
# Out:
# ...
#      |████████████████████████████████| 320.4MB 52kB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob as gb
from os import rename
files = gb.glob('/content/drive/My Drive/Building_Detection/data/patches_data/*.tif')
for f in files:
  n = f.split('.t')[0]
  n = n.replace('.','_')
  print(n)
  rename(f, n+'.tif')
# Out:
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_16
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_30
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_17
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_15
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_26
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_27
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_18
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_28
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_31
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_25
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_19
# /content/drive/My Drive/Building_Detection/data/patches_data/qgis_patch_29
# ...

# %%
import glob as gb
import cv2
from PIL import Image
import numpy as np
from os import rename
import os
files = gb.glob('/content/drive/My Drive/Building_Detection/data/resized_data_mask/*.tif')
for f in files:
  im = Image.open(f)
  print(f)
  
  img = np.array(im)
  res = cv2.resize(img,(400,400))
  sv = os.path.join('/content/drive/My Drive/Building_Detection/data/masks' , f.split('k/')[1])
  print(sv)
  cv2.imwrite(sv, res)
# Out:
# /content/drive/My Drive/Building_Detection/data/resized_data_mask/qgis_patch_1000.tif
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# /content/drive/My Drive/Building_Detection/data/masks/qgis_patch_1000.tif
# /content/drive/My Drive/Building_Detection/data/resized_data_mask/qgis_patch_743.tif
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# /content/drive/My Drive/Building_Detection/data/masks/qgis_patch_743.tif
# /content/drive/My Drive/Building_Detection/data/resized_data_mask/qgis_patch_1001.tif
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.0'

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 18.2MB/s
# ...

# %%
# !python3 /content/drive/My\ Drive/Building_Detection/src/models/fine_tune_model.py --dataset /content/drive/My\ Drive/Building_Detection/data/dataSplit --images /content/drive/My\ Drive/Building_Detection/data/resized_data --labels /content/drive/My\ Drive/Building_Detection/data/newd
# Out:
# 2021-01-23 08:13:31.270623: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# GPU: -1
# # Minibatch-size: 1
# # Crop-size: 400
# # epoch: 100
#
# 2021-01-23 08:13:38.121718: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-23 08:13:38.122082: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-23 08:13:38.175882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-23 08:13:38.176513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !cd /content
# !cd /content/drive/MyDrive/VMG/Vector-Map-Generation-from-Aerial-Imagery-using-Deep-Learning-GeoSpatial-UNET-master
# !python3 /content/drive/MyDrive/VMG/Vector-Map-Generation-from-Aerial-Imagery-using-Deep-Learning-GeoSpatial-UNET-master/test.py
# Out:
# 2021-01-24 15:24:23.423462: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/VMG/Vector-Map-Generation-from-Aerial-Imagery-using-Deep-Learning-GeoSpatial-UNET-master/test.py", line 16, in <module>
#     from src import postprocess
#   File "/content/drive/MyDrive/VMG/Vector-Map-Generation-from-Aerial-Imagery-using-Deep-Learning-GeoSpatial-UNET-master/src/postprocess.py", line 2, in <module>
#     import shapefile
# ModuleNotFoundError: No module named 'shapefile'

# %%
# !cd /content/drive/My\ Drive/Building_Detection/src/models
# !python3 /content/drive/My\ Drive/Building_Detection/src/models/predict.py
# Out:
# 2021-01-11 17:54:15.481895: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-11 17:54:21.673527: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-11 17:54:21.673872: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-11 17:54:21.725863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-11 17:54:21.726487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !cd /content/drive/My\ Drive/Building_Detection/src/models
# !python3 /content/drive/My\ Drive/Building_Detection/src/models/predict.py
# Out:
# 2021-01-11 17:54:15.481895: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-11 17:54:21.673527: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-11 17:54:21.673872: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-11 17:54:21.725863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-11 17:54:21.726487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !python3 /content/drive/My\ Drive/Building_Detection/src/models/test.py
# Out:
# 2021-01-13 15:15:30.137449: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-13 15:15:32.436737: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-13 15:15:32.436911: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-13 15:15:32.477606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-13 15:15:32.478165: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

fig = plt.figure()
#in_img = mpimg.imread('in.jpg')
img = mpimg.imread('result.jpg')
#ax1 = fig.add_subplot(1,2,1)
#ax1.imshow(in_img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img)

plt.show()

# %%
# !tensorboard --logdir ./content/drive/My\ Drive/Building_Detection/tensorboard
# Out:
# 2020-10-09 16:05:46.438915: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.3.0 at http://localhost:6006/ (Press CTRL+C to quit)

# %%
from keras.models import load_model

import cv2

import numpy as np

model = load_model('model.h5')

model.compile(loss='binary_crossentropy',

              optimizer='Adam',

              metrics=['accuracy'])

img = cv2.imread('test.jpg')

img = cv2.resize(img,(400,400))

img = np.reshape(img,[1,400,400,3])

classes = model.predict_classes(img)

print classes

It outputs:

[[0]]
